# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt
import opendatasets as od

# %%
df = pd.read_csv("credit-card-transactions-dataset/credit_card_transactions.csv")

# %%
conn = sqlite3.connect("transactions.db")
c = conn.cursor()
c.execute("""
    CREATE TABLE IF NOT EXISTS merchants(
        id   INTEGER PRIMARY KEY,
        name TEXT NOT NULL
    );

    CREATE TABLE IF NOT EXISTS categories(
        id,
        name,
        parent_id,
        
    );

    CREATE TABLE IF NOT EXISTS transactions(
        id           INTEGER PRIMARY KEY, 
        date         TEXT NOT NULL, 
        description  TEXT, 
        amount       REAL NOT NULL, 
        merchant_id  INTEGER, 
        category_id  INTEGER,
        FOREIGN KEY(merchant_id) REFERENCES merchants(id),
        FOREIGN KEY(category_id) REFERENCES categories(id)
    );
    
""")
c.execute("CREATE TABLE merchants(id, name)")
c.execute("CREATE TABLE categories(id, name, parent_id)")
c.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 3
#       1 conn = sqlite3.connect("transactions.db")
#       2 c = conn.cursor()
# ----> 3 c.execute("CREATE TABLE transactions(id, date, description, amount, merchant_id, category_id)")
#       4 c.execute("CREATE TABLE merchants(id, name)")
#       5 c.execute("CREATE TABLE categories(id, name, parent_id)")
#
# OperationalError: table transactions already exists

# %%
c.execute("INSERT INTO transactions(id, date, description, amount, merchant_id, category_id) values(1, 20, Sth, 23, 23, 22)")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 c.execute("INSERT INTO transactions(id, date, description, amount, merchant_id, category_id) values(1, 20, Sth, 23, 23, 22)")
#
# OperationalError: no such column: Sth

# %%
for row in c.execute("SELECT * FROM transactions"):
    print(row)
